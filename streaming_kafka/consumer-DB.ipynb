# %%
from dataclasses import dataclass

@dataclass
class Ride:
    PULocationID: int
    DOLocationID: int
    trip_distance: float
    total_amount: float
    tpep_pickup_datetime: int

# %%
import json

def ride_deserializer(data):
    json_str = data.decode('utf-8')
    ride_dict = json.loads(json_str)
    return Ride(**ride_dict)

# %%
from kafka import KafkaConsumer

server = 'localhost:9092'
topic_name = 'rides'

consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',
    #group_id='rides-console',
    group_id='rides-to-postgres',
    value_deserializer=ride_deserializer
)
# Out:
# /tmp/ipykernel_8904/2243439258.py:6: DeprecationWarning: value_deserializer does not implement kafka.serializer.Deserializer
#   consumer = KafkaConsumer(

# %%
import psycopg2

conn = psycopg2.connect(
    host='localhost',
    port=5432,
    database='postgres',
    user='postgres',
    password='postgres'
)
conn.autocommit = True
cur = conn.cursor()

# %%
from datetime import datetime

print(f"Listening to {topic_name} and writing to PostgreSQL...")

count = 0
for message in consumer:
    ride = message.value
    pickup_dt = datetime.fromtimestamp(ride.tpep_pickup_datetime / 1000)
    cur.execute(
        """INSERT INTO processed_events
           (PULocationID, DOLocationID, trip_distance, total_amount, pickup_datetime)
           VALUES (%s, %s, %s, %s, %s)""",
        (ride.PULocationID, ride.DOLocationID,
         ride.trip_distance, ride.total_amount, pickup_dt)
    )
    count += 1
    if count % 100 == 0:
        print(f"Inserted {count} rows...")

consumer.close()
cur.close()
conn.close()
# Out:
# Listening to rides and writing to PostgreSQL...
# Inserted 100 rows...
# Inserted 200 rows...
# Inserted 300 rows...
# Inserted 400 rows...
# Inserted 500 rows...
# Inserted 600 rows...
# Inserted 700 rows...
# Inserted 800 rows...
# Inserted 900 rows...
# Inserted 1000 rows...
# Inserted 1100 rows...
# Inserted 1200 rows...
# Inserted 1300 rows...
# Inserted 1400 rows...
# Inserted 1500 rows...
# Inserted 1600 rows...
# Inserted 1700 rows...
# Inserted 1800 rows...
# Inserted 1900 rows...
# Inserted 2000 rows...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       2
#       3 print(f"Listening to {topic_name} and writing to PostgreSQL...")
#       4
#       5 count = 0
# ----> 6 for message in consumer:
#       7     ride = message.value
#       8     pickup_dt = datetime.fromtimestamp(ride.tpep_pickup_datetime / 1000)
#       9     cur.execute(
#
# File ~/Data-engineering-zoomcamp/streaming_kafka/.venv/lib/python3.14/site-packages/kafka/consumer/group.py:1358, in KafkaConsumer.__next__(self)
#    1356     self._iterator = self._message_generator_v2()
#    1357 try:
# -> 1358     return next(self._iterator)
#    1359 except StopIteration:
#    1360     self._iterator = None
#
# File ~/Data-engineering-zoomcamp/streaming_kafka/.venv/lib/python3.14/site-packages/kafka/consumer/group.py:1329, in KafkaConsumer._message_generator_v2(self)
#    1327 def _message_generator_v2(self):
#    1328     timeout_ms = 1000 * max(0, self._consumer_timeout - time.monotonic())
# -> 1329     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1330     for tp, records in record_map.items():
#    1331         # Generators are stateful, and it is possible that the tp / records
#    1332         # here may become stale during iteration -- i.e., we seek to a
#    1333         # different offset, pause consumption, or lose assignment.
#    1334         for record in records:
#    1335             # is_fetchable(tp) should handle assignment changes and offset
#    1336             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1337             # outer function destroying the existing iterator/generator
#    1338             # via self._iterator = None
#
# File ~/Data-engineering-zoomcamp/streaming_kafka/.venv/lib/python3.14/site-packages/kafka/consumer/group.py:827, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     825 timer = Timer(timeout_ms)
#     826 while not self._closed:
# --> 827     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     828     if records:
#     829         return records
#
# File ~/Data-engineering-zoomcamp/streaming_kafka/.venv/lib/python3.14/site-packages/kafka/consumer/group.py:865, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     862 if self.config['group_id'] is not None:
#     863     poll_timeout_ms = min(poll_timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 865 records, idle = self._fetcher.fetch_records(
#     866     max_records, update_offsets=update_offsets, timeout_ms=poll_timeout_ms)
#     867 if not records and idle and poll_timeout_ms > 0:
#     868     # Nothing fetchable and nothing in flight (no assignment, all
#     869     # paused, or no resolvable positions). Sleep up to poll_timeout_ms
#     870     # to avoid busy-looping; poll_timeout_ms is already capped by the
#     871     # coordinator's next-action deadline.
#     872     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
#
# File ~/Data-engineering-zoomcamp/streaming_kafka/.venv/lib/python3.14/site-packages/kafka/consumer/fetcher.py:261, in Fetcher.fetch_records(self, max_records, update_offsets, timeout_ms)
#     258     fut.add_both(_wake)
#     260 try:
# --> 261     self._net.run(self._manager.wait_for, wakeup, timeout_ms)
#     262 except Errors.KafkaTimeoutError:
#     263     pass
#
# File ~/Data-engineering-zoomcamp/streaming_kafka/.venv/lib/python3.14/site-packages/kafka/net/selector.py:330, in NetworkSelector.run(self, coro, *args)
#     328     self._pending_waiters[event] = state
#     329 self.call_soon_threadsafe(waiter)
# --> 330 event.wait()
#     331 if state['exception'] is not None:
#     332     raise state['exception']  # pylint: disable=E0702
#
# File ~/.local/share/uv/python/cpython-3.14.7-linux-x86_64-gnu/lib/python3.14/threading.py:670, in Event.wait(self, timeout)
#     668 signaled = self._flag
#     669 if not signaled:
# --> 670     signaled = self._cond.wait(timeout)
#     671 return signaled
#
# File ~/.local/share/uv/python/cpython-3.14.7-linux-x86_64-gnu/lib/python3.14/threading.py:369, in Condition.wait(self, timeout)
#     367 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     368     if timeout is None:
# --> 369         waiter.acquire()
#     370         gotit = True
#     371     else:
#
# KeyboardInterrupt:
