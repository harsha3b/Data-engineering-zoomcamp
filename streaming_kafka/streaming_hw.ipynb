# %% [markdown]
# Run rpk version inside the Redpanda container:
# ### 1) What version of Redpanda are you running?
#
# docker exec -it streaming_kafka-redpanda-1 rpk version
#
# answer) rpk version: v25.3.9

# %% [markdown]
# ### 2) Create a topic called green-trips
#
# docker exec -it streaming_kafka-redpanda-1 rpk topic create green-trips
#
# answer) took 558.19 seconds

# %% [markdown]
# ### 3) Consumer - trip distance
# Write a Kafka consumer that reads all messages from the green-trips topic (set auto_offset_reset='earliest').
#
# Count how many trips have a trip_distance greater than 5.0 kilometers.
#
# How many trips have trip_distance > 5?
#
# 1) 6506
# 2) 7506
# 3) 8506
# 4) 9506
#
# answer) 8506

# %% [markdown]
# ### 4)  Tumbling window - pickup location
# Create a Flink job that reads from green-trips and uses a 5-minute tumbling window to count trips per PULocationID.
#
# Which PULocationID had the most trips in a single 5-minute window?
#
# 1) 42
# 2) 74
# 3) 75
# 4) 166
#
# answer) 74

# %% [markdown]
# ### 5) How many trips were in the longest session?
#
# 1) 12
# 2) 31
# 3) 51
# 4) 81
#
# answer) 81

# %% [markdown]
# ### 6) Tumbling window - largest tip
# Which hour had the highest total tip amount?
#
# 1) 2025-10-01 18:00:00
# 2) 2025-10-16 18:00:00
# 3) 2025-10-22 08:00:00
# 4) 2025-10-30 16:00:00
#
# answer) 2025-10-16 18:00:00
